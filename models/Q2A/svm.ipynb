# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('allseasons.csv')
df = df.drop(['Unnamed: 0'], axis=1)

# %%
import pandas as pd
from sklearn.svm import SVC  
from sklearn.model_selection import train_test_split
from sklearn.multioutput import MultiOutputClassifier
from sklearn.metrics import accuracy_score


# Assuming df is your DataFrame
ml_df = df.iloc[:, 11:]  # type: ignore
features = ml_df[['Surface_Salinity','Bottom_Salinity','salt_strat', 'Surface_Temp','Bottom_Temp','temp_strat']]
labels = ml_df.loc[:,'Atl_croaker_(nibea98)':'Atl_salmon'].applymap(lambda x: 1 if x > 0 else 0)

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(features, labels, test_size=0.3, random_state=109)  

# Check unique values in each column of y_train and filter out columns with only one unique value
valid_columns = [col for col in y_train.columns if y_train[col].nunique() > 1]
y_train_filtered = y_train[valid_columns]
y_test_filtered = y_test[valid_columns]

clf = MultiOutputClassifier(SVC(kernel='linear'))
clf.fit(X_train, y_train_filtered)
y_pred = clf.predict(X_test)

accuracies = {}
for i, col in enumerate(valid_columns):
    accuracies[col] = accuracy_score(y_test_filtered.iloc[:, i], y_pred[:, i])

# Calculate overall accuracy
overall_accuracy = sum(accuracies.values()) / len(accuracies)

# Print the results
for species, accuracy in accuracies.items():
    print(f'Accuracy for {species}: {accuracy:.4f}')

print(f'Overall accuracy: {overall_accuracy:.4f}')
# Out:
# Accuracy for Atl_croaker_(nibea98): 0.9231
# Accuracy for Bay_anchovy: 0.9615
# Accuracy for Black_drum_or_Spot: 0.8846
# Accuracy for Black_sea_bass: 0.7692
# Accuracy for Brd_striped_anchovy: 0.8462
# Accuracy for Little_tunny_or_skipjack_tuna: 0.9615
# Accuracy for Nor_sea_robin: 0.8846
# Accuracy for Scup: 0.7308
# Accuracy for Smallmouth_flounder: 0.7692
# Accuracy for Southern_kingfish(nibea95): 0.6538
# Accuracy for Str_sea_robin: 0.6923
# Accuracy for Summ_flounder: 0.9231
# Accuracy for Summ_flounder99a: 0.5385
# Accuracy for Weakfish_Cyn: 0.7308
# Accuracy for Windowpane_flounder: 1.0000
# Accuracy for Am_butterfish: 0.8846
# Accuracy for Atl_chub_mackerel: 1.0000
# Accuracy for Frigate_or_bullet_tuna: 0.9231
# Accuracy for Giant_trevally99: 0.8846
# Accuracy for Hogchoker_trinectes: 0.8846
# Accuracy for Nor_kingfish: 0.7692
# Accuracy for Red_White_or_Spotted_hake: 0.8462
# Accuracy for Spanish_mackerel: 0.9231
# Accuracy for Tautog: 0.6154
# Accuracy for Thread_herring: 0.8846
# Accuracy for Atl_menhaden_LS16_or_river_herrings: 0.9615
# Accuracy for Cobia: 0.8846
# Accuracy for Cunner: 0.8846
# Accuracy for Am_conger: 0.8077
# Accuracy for Atl_or_nor_sand_lance: 0.4615
# Accuracy for Bluefish: 0.8462
# Accuracy for Silver_anchovy: 0.8846
# Accuracy for Seaboard_goby: 0.7308
# Accuracy for Nor_puffer: 0.8462
# Accuracy for Silver_perch(nibea93): 0.6154
# Accuracy for Sturgeon: 0.6538
# Accuracy for Crested_blenny_refseq_not_full_length: 1.0000
# Accuracy for Str_burrfish: 1.0000
# Accuracy for Dwarf_goatfish: 0.9615
# Accuracy for Fourspot_flounder: 0.6538
# Accuracy for Nor_sennet95: 0.8846
# Accuracy for Atl_moonfish: 1.0000
# Accuracy for Atl_silverside: 0.8846
# Accuracy for Gulf_stream_flounder: 0.8462
# Accuracy for Str_cusk_eel: 0.9615
# Accuracy for Grey_triggerfish: 1.0000
# Accuracy for Nor_pipefish: 0.8462
# Accuracy for Planehead_filefish: 1.0000
# Accuracy for Rough_scad: 0.7692
# Accuracy for Mummichog: 0.8846
# Accuracy for Rough_silverside94: 0.9231
# Accuracy for Sheepshead_minnow: 0.9615
# Accuracy for Str_bass: 0.9231
# Accuracy for White_mullet: 1.0000
# Accuracy for Am_eel: 0.9231
# Accuracy for Red_eye_round_herring: 1.0000
# Accuracy for Atl_mackerel: 1.0000
# Accuracy for Flathead_grey_mullet: 0.8846
# Accuracy for Silver_hake: 0.5769
# Accuracy for Winter_or_Yellowtail_flounder: 0.7692
# Accuracy for Atl_herring: 0.8846
# Accuracy for Atl_cod: 0.9615
# Accuracy for Catfish_sp: 1.0000
# Accuracy for White_perch: 0.9231
# Accuracy for Whitefish_Cor: 1.0000
# Accuracy for Pac_sand_lance: 1.0000
# Accuracy for Atl_salmon: 1.0000
# Overall accuracy: 0.8639
